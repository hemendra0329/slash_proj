# %%
import numpy 
import duckdb

con = duckdb.connect("dev.duckdb")

# %%
df = con.execute("SELECT * FROM card_transactions LIMIT 5")

# %%
print(df.fetchdf())
# Out:
#           TRANSACTION_ID     SUBACCOUNT_ID          CARD_ID ACCOUNT_TYPE  \
# 0  te_card_10003l0ftibyu   sa_vtzf9ugf6bj7  c_2a02q7rl1sv75   commercial
# 1  te_card_10008vpqejie2  sa_150nue2tsm09s  c_3igv5vme7t5yh   commercial
# 2  te_card_1000cl901djzq  sa_1t0xagibi2n3p  c_29hi8mban27wg   commercial
# 3  te_card_1000i3fdzsu0s  sa_1pvszadz89hov   c_6vsw0mg46wgb   commercial
# 4  te_card_1000k2gpwoj0s  sa_28w72wks30ak3  c_257nqzgkdnztn   commercial
#
#    TRANSACTION_AMOUNT ORIGINAL_CURRENCY_CODE    MERCHANT_DESCRIPTION  \
# 0           -5.000000                    USD                 VISIBLE
# 1         -105.900002                    USD        TM *TICKETMASTER
# 2          -20.000000                    USD  OPENAI *CHATGPT SUBSCR
# 3         -109.989998                    USD   Gandi order 125944545
# 4         -530.000000                    USD  TM *AFTERLIFE PRESENTS
#
#   MERCHANT_CATEGORY_CODE MERCHANT_COUNTRY               TIMESTAMP
# ...
